# %%
import numpy as np
import pandas as pd
import pyarrow.parquet as pq
import duckdb

# %%
con = duckdb.connect()
con.execute("""-- Set memory limits before running query
                SET memory_limit='16GB';
                -- Enable progress tracking
                SET enable_progress_bar=true;
                -- Enable detailed profiling
                SET profiling_mode='detailed';
            """)

# %%
# Define file path and view name
parquet_path = "/Users/couch/intel_research/data/0000_part_00 (1).parquet"
view_name = "parquet_view"

# Create a view over the Parquet file
con.execute(f"""
    CREATE VIEW {view_name} AS 
    SELECT * FROM read_parquet('{parquet_path}');
""")

# %%
df = con.execute(f"SELECT * FROM {view_name} LIMIT 5").fetchdf()
print(df)
# Out:
#               load_ts         batch_id  \
# 0 2019-10-24 04:09:21  20191023-210226
# 1 2019-10-24 04:09:21  20191023-210226
# 2 2019-10-24 04:09:21  20191023-210226
# 3 2019-10-24 04:09:21  20191023-210226
# 4 2019-10-24 04:09:21  20191023-210226
#
#                                            audit_zip  \
# 0  2019102316-i-0728cf8ab79db9e58-BfZXhQdKBpG8dxo...
# 1  2019102316-i-0728cf8ab79db9e58-BfZXhQdKBpG8dxo...
# 2  2019102316-i-0728cf8ab79db9e58-BfZXhQdKBpG8dxo...
# 3  2019102316-i-0728cf8ab79db9e58-BfZXhQdKBpG8dxo...
# 4  2019102316-i-0728cf8ab79db9e58-BfZXhQdKBpG8dxo...
#
#                            audit_internal_path  \
# 0  V8_1_SYSTEMUSAGEBYFGNDAPP_20191023231918.V8
# 1  V8_1_SYSTEMUSAGEBYFGNDAPP_20191023231918.V8
# 2  V8_1_SYSTEMUSAGEBYFGNDAPP_20191023231918.V8
# 3  V8_1_SYSTEMUSAGEBYFGNDAPP_20191023231918.V8
# 4  V8_1_SYSTEMUSAGEBYFGNDAPP_20191023231918.V8
#
#                                guid  interval_start_utc    interval_end_utc  \
# 0  0028155e73c04ed2a420eb00af9e3105 2019-10-22 16:15:01 2019-10-23 16:19:35
# 1  0028155e73c04ed2a420eb00af9e3105 2019-10-22 16:15:01 2019-10-23 16:19:35
# 2  0028155e73c04ed2a420eb00af9e3105 2019-10-22 16:15:01 2019-10-23 16:19:35
# 3  0028155e73c04ed2a420eb00af9e3105 2019-10-22 16:15:01 2019-10-23 16:19:35
# 4  0028155e73c04ed2a420eb00af9e3105 2019-10-22 16:15:01 2019-10-23 16:19:35
#
#   interval_local_start  interval_local_end                  ts  ...  \
# 0  2019-10-22 23:15:02 2019-10-23 23:19:35 2019-10-22 23:15:38  ...
# 1  2019-10-22 23:15:02 2019-10-23 23:19:35 2019-10-22 23:15:38  ...
# 2  2019-10-22 23:15:02 2019-10-23 23:19:35 2019-10-22 23:15:38  ...
# 3  2019-10-22 23:15:02 2019-10-23 23:19:35 2019-10-22 23:16:26  ...
# 4  2019-10-22 23:15:02 2019-10-23 23:19:35 2019-10-22 23:16:26  ...
#
#                         metric_name  aggregation_type attribute_level1 nrs  \
# 0            HW::CORE:AVG_FREQ:MHZ:                 2                0   6
# 1              HW::CORE:C0:PERCENT:                 1                0   6
# 2  HW::CORE:TEMPERATURE:CENTIGRADE:                 2                0   6
# 3            HW::CORE:AVG_FREQ:MHZ:                 2                0  11
# 4              HW::CORE:C0:PERCENT:                 1                0  11
#
#    avg_val  min_val  max_val  percentile_50th percentile_75th  percentile_90th
# 0  2354.76  2317.16  2429.45          2341.51         2362.33          2398.16
# 1    51.09    29.97    74.00            49.84           63.18            70.30
# 2    60.83    55.00    69.00            60.50           65.00            67.00
# 3  2428.58  2380.04  2450.60          2427.66         2442.67          2446.67
# 4    24.24    15.56    36.85            23.27           27.42            36.31
#
# [5 rows x 26 columns]
# ┌─────────────────────────────────────┐
# │┌───────────────────────────────────┐│
# ││    Query Profiling Information    ││
# │└───────────────────────────────────┘│
# └─────────────────────────────────────┘
# SELECT * FROM parquet_view LIMIT 5
# ┌────────────────────────────────────────────────┐
# │┌──────────────────────────────────────────────┐│
# ││              Total Time: 0.0318s             ││
# │└──────────────────────────────────────────────┘│
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │               Optimizer: 0.0023s               │
# │┌──────────────────────────────────────────────┐│
# ││        Build Side Probe Side: 0.0000s        ││
# ││           Column Lifetime: 0.0000s           ││
# ││           Common Aggregate: 0.0000s          ││
# ││        Common Subexpressions: 0.0000s        ││
# ││      Compressed Materialization: 0.0000s     ││
# ││          Cte Filter Pusher: 0.0000s          ││
# ││             Deliminator: 0.0000s             ││
# ││           Duplicate Groups: 0.0000s          ││
# ││         Empty Result Pullup: 0.0000s         ││
# ││         Expression Rewriter: 0.0000s         ││
# ││              Extension: 0.0000s              ││
# ││            Filter Pullup: 0.0000s            ││
# ││           Filter Pushdown: 0.0000s           ││
# ││              In Clause: 0.0000s              ││
# ││         Join Filter Pushdown: 0.0000s        ││
# ││              Join Order: 0.0012s             ││
# ││         Late Materialization: 0.0000s        ││
# ││            Limit Pushdown: 0.0000s           ││
# ││           Materialized Cte: 0.0000s          ││
# ││             Regex Range: 0.0000s             ││
# ││            Reorder Filter: 0.0000s           ││
# ││          Sampling Pushdown: 0.0000s          ││
# ││        Statistics Propagation: 0.0010s       ││
# ││             Sum Rewriter: 0.0000s            ││
# ││                Top N: 0.0000s                ││
# ││           Unnest Rewriter: 0.0000s           ││
# ││            Unused Columns: 0.0000s           ││
# │└──────────────────────────────────────────────┘│
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │            Physical planner: 0.0000s           │
# │┌──────────────────────────────────────────────┐│
# ││            Column Binding: 0.0000s           ││
# ││             Create Plan: 0.0000s             ││
# ││            Resolve Types: 0.0000s            ││
# │└──────────────────────────────────────────────┘│
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │                Planner: 0.0031s                │
# │┌──────────────────────────────────────────────┐│
# ││               Binding: 0.0031s               ││
# │└──────────────────────────────────────────────┘│
# └─────────────────────────────────────────���──────┘
# ┌───────────────────────────┐
# │           QUERY           │
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │      STREAMING_LIMIT      │
# │    ────────────────────   │
# │           5 Rows          │
# │          (0.00s)          │
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │         TABLE_SCAN        │
# │    ────────────────────   │
# │         Function:         │
# │        READ_PARQUET       │
# │                           │
# │        Projections:       │
# │          load_ts          │
# │          batch_id         │
# │         audit_zip         │
# │    audit_internal_path    │
# │            guid           │
# │     interval_start_utc    │
# │      interval_end_utc     │
# │    interval_local_start   │
# │     interval_local_end    │
# │             ts            │
# │             dt            │
# │            pid            │
# │         proc_name         │
# │        proc_package       │
# │         captioned         │
# │          duration         │
# │        metric_name        │
# │      aggregation_type     │
# │      attribute_level1     │
# │            nrs            │
# │          avg_val          │
# │          min_val          │
# │          max_val          │
# │      percentile_50th      │
# │      percentile_75th      │
# │      percentile_90th      │
# │                           │
# │         4096 Rows         │
# │          (0.02s)          │
# └───────────────────────────┘

# %%
df.columns
# Out:
# Index(['load_ts', 'batch_id', 'audit_zip', 'audit_internal_path', 'guid',
#        'interval_start_utc', 'interval_end_utc', 'interval_local_start',
#        'interval_local_end', 'ts', 'dt', 'pid', 'proc_name', 'proc_package',
#        'captioned', 'duration', 'metric_name', 'aggregation_type',
#        'attribute_level1', 'nrs', 'avg_val', 'min_val', 'max_val',
#        'percentile_50th', 'percentile_75th', 'percentile_90th'],
#       dtype='object')

# %%
df = con.execute(f"SELECT DISTINCT proc_name FROM {view_name}").fetchdf()
print(df)
# Out:
#                               proc_name
# 0                    steamwebhelper.exe
# 1      keepuppirates-win64-shipping.exe
# 2                          pet idle.exe
# 3                             whale.exe
# 4                             debut.exe
# ...                                 ...
# 29177                   gamebrowser.exe
# 29178            marsserverprovider.exe
# 29179                     delftship.exe
# 29180             l2soft.eu updater.exe
# 29181          spark_2_9_4-with-jre.exe
#
# [29182 rows x 1 columns]
# ┌─────────────────────────────────────┐
# │┌───────────────────────────────────┐│
# ││    Query Profiling Information    ││
# │└───────────────────────────────────┘│
# └─────────────────────────────────────┘
# SELECT DISTINCT proc_name FROM parquet_view
# ┌────────────────────────────────────────────────┐
# │┌──────────────────────────────────────────────┐│
# ││              Total Time: 0.121s              ││
# │└──────────────────────────────────────────────┘│
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │               Optimizer: 0.0010s               │
# │┌──────────────────────────────────────────────┐│
# ││        Build Side Probe Side: 0.0000s        ││
# ││           Column Lifetime: 0.0000s           ││
# ││           Common Aggregate: 0.0000s          ││
# ││        Common Subexpressions: 0.0000s        ││
# ││      Compressed Materialization: 0.0000s     ││
# ││          Cte Filter Pusher: 0.0000s          ││
# ││             Deliminator: 0.0000s             ││
# ││           Duplicate Groups: 0.0000s          ││
# ││         Empty Result Pullup: 0.0000s         ││
# ││         Expression Rewriter: 0.0000s         ││
# ││              Extension: 0.0000s              ││
# ││            Filter Pullup: 0.0000s            ││
# ││           Filter Pushdown: 0.0000s           ││
# ││              In Clause: 0.0000s              ││
# ││         Join Filter Pushdown: 0.0000s        ││
# ││              Join Order: 0.0009s             ││
# ││         Late Materialization: 0.0000s        ││
# ││            Limit Pushdown: 0.0000s           ││
# ││           Materialized Cte: 0.0000s          ││
# ││             Regex Range: 0.0000s             ││
# ││            Reorder Filter: 0.0000s           ││
# ││          Sampling Pushdown: 0.0000s          ││
# ││        Statistics Propagation: 0.0000s       ││
# ││             Sum Rewriter: 0.0000s            ││
# ││                Top N: 0.0000s                ││
# ││           Unnest Rewriter: 0.0000s           ││
# ││            Unused Columns: 0.0000s           ││
# │└──────────────────────────────────────────────┘│
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │            Physical planner: 0.0000s           │
# │┌──────────────────────────────────────────────┐│
# ││            Column Binding: 0.0000s           ││
# ││             Create Plan: 0.0000s             ││
# ││            Resolve Types: 0.0000s            ││
# │└──────────────────────────────────────────────┘│
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │                Planner: 0.0035s                │
# │┌──────────────────────────────────────────────┐│
# ││               Binding: 0.0035s               ││
# │└──────────────────────────────────────────────┘│
# └──────────────────────────────────────���─────────┘
# ┌───────────────────────────┐
# │           QUERY           │
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │       HASH_GROUP_BY       │
# │    ────────────────────   │
# │         Groups: #0        │
# │                           │
# │         29182 Rows        │
# │          (0.21s)          │
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │         PROJECTION        │
# │    ────────────────────   │
# │         proc_name         │
# │                           │
# │       210541713 Rows      │
# │          (0.01s)          │
# └��────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │         TABLE_SCAN        │
# │    ────────────────────   │
# │         Function:         │
# │        READ_PARQUET       │
# │                           │
# │        Projections:       │
# │         proc_name         │
# │                           │
# │    Total Files Read: 1    │
# │                           │
# │       210541713 Rows      │
# │          (0.87s)          │
# └───────────────────────────┘

# %%
df = con.execute(f"SELECT DISTINCT aggregation_type FROM {view_name}").fetchdf()
print(df)
# Out:
#    aggregation_type
# 0                 0
# 1                 2
# 2                 1
# ┌─────────────────────────────────────┐
# │┌───────────────────────────────────┐│
# ││    Query Profiling Information    ││
# │└───────────────────────────────────┘│
# └─────────────────────────────────────┘
# SELECT DISTINCT aggregation_type FROM parquet_view
# ┌────────────────────────────────────────────────┐
# │┌──────────────────────────────────────────────┐│
# ││              Total Time: 0.0769s             ││
# │└────────────────────��─────────────────────────┘│
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │               Optimizer: 0.0017s               │
# │┌──────────────────────────────────────────────┐│
# ││        Build Side Probe Side: 0.0000s        ││
# ││           Column Lifetime: 0.0000s           ││
# ││           Common Aggregate: 0.0000s          ││
# ││        Common Subexpressions: 0.0000s        ││
# ││      Compressed Materialization: 0.0000s     ││
# ││          Cte Filter Pusher: 0.0000s          ││
# ││             Deliminator: 0.0000s             ││
# ││           Duplicate Groups: 0.0000s          ││
# ││         Empty Result Pullup: 0.0000s         ││
# ││         Expression Rewriter: 0.0000s         ││
# ││              Extension: 0.0000s              ││
# ││            Filter Pullup: 0.0000s            ││
# ││           Filter Pushdown: 0.0000s           ││
# ││              In Clause: 0.0000s              ││
# ││         Join Filter Pushdown: 0.0000s        ││
# ││              Join Order: 0.0008s             ││
# ││         Late Materialization: 0.0000s        ││
# ││            Limit Pushdown: 0.0000s           ││
# ││           Materialized Cte: 0.0000s          ││
# ││             Regex Range: 0.0000s             ││
# ││            Reorder Filter: 0.0000s           ││
# ││          Sampling Pushdown: 0.0000s          ││
# ││        Statistics Propagation: 0.0009s       ││
# ││             Sum Rewriter: 0.0000s            ││
# ││                Top N: 0.0000s                ││
# ││           Unnest Rewriter: 0.0000s           ││
# ││            Unused Columns: 0.0000s           ││
# │└──────────────────────────────────────────────┘│
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │            Physical planner: 0.0000s           │
# │┌──────────────────────────────────────────────┐│
# ││            Column Binding: 0.0000s           ││
# ││             Create Plan: 0.0000s             ││
# ││            Resolve Types: 0.0000s            ││
# │└──────────────────────────────────────────────┘│
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │                Planner: 0.0029s                │
# │┌──────────────────────────────────────────────┐│
# ││               Binding: 0.0029s               ││
# │└──────────────────────────────────────────────┘│
# └────────────────────────────────────────────────┘
# ┌───────────────────────────┐
# │           QUERY           │
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │         PROJECTION        │
# │    ────────────────────   │
# │__internal_decompress_integ│
# │    ral_smallint(#0, 0)    │
# │                           │
# │           3 Rows          │
# │          (0.00s)          │
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │       HASH_GROUP_BY       │
# │    ────────────────────   │
# │         Groups: #0        │
# │                           │
# │           3 Rows          ��
# │          (0.22s)          │
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │         PROJECTION        │
# │    ────────────────────   │
# │      aggregation_type     │
# │                           │
# │       210541713 Rows      │
# │          (0.01s)          │
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │         PROJECTION        │
# │    ────────────────────   │
# │__internal_compress_integra│
# │     l_utinyint(#0, 0)     │
# │                           │
# │       210541713 Rows      │
# │          (0.06s)          │
# └─────────────┬─────────────┘
# ��─────────────┴─────────────┐
# │         TABLE_SCAN        │
# │    ────────────────────   │
# │         Function:         │
# │        READ_PARQUET       │
# │                           │
# │        Projections:       │
# │      aggregation_type     │
# │                           │
# │    Total Files Read: 1    │
# │                           │
# │       210541713 Rows      │
# │          (0.35s)          │
# └───────────────────────────┘

# %%
# views allow many queries to be run on the same data without having to re-read it from disk.
create_view = """
    CREATE VIEW {view_name} AS 
        SELECT * FROM read_parquet('{parquet_path}');
"""

# %%
webcat_data = pq.ParquetDataset("/Users/couch/intel_research/data/webcat_pivot")
table = webcat_data.read()
print(table.schema)
# Out:
# guid: string
# social_social_network: int64
# private_private: int64
# productivity_word_processing: int64
# news_news: int64
# social_communication: int64
# productivity_spreadsheets: int64
# content_creation_photo_edit_creation: int64
# search_search: int64
# productivity_other: int64
# entertainment_music_audio_streaming: int64
# finance_banking_and_accounting: int64
# games_other: int64
# entertainment_other: int64
# education_education: int64
# productivity_programming: int64
# productivity_presentations: int64
# reference_reference: int64
# shopping_shopping: int64
# other_unclassified: int64
# recreation_travel: int64
# entertainment_video_streaming: int64
# games_video_games: int64
# productivity_crm: int64
# mail_mail: int64
# social_communication_live: int64
# content_creation_video_audio_edit_creation: int64
# productivity_project_management: int64
# content_creation_web_design_development: int64

# %%
parquet_path = "/Users/couch/intel_research/data/webcat_pivot"
view_name = "webcat_view"

con.execute(f"""
    CREATE VIEW {view_name} AS 
    SELECT * FROM read_parquet('{parquet_path}');
""")

# %%
con.execute(f"SELECT * FROM {view_name} LIMIT 5").fetchdf()
# Out:
# ┌─────────────────────────────────────┐
# │┌───────────────────────────────────┐│
# ││    Query Profiling Information    ││
# │└───────────────────────────────────┘│
# └─────────────────────────────────────┘
# SELECT * FROM webcat_view LIMIT 5
# ┌────────────────────────────────────────────────┐
# │┌──────────────────────────────────────────────┐│
# ││              Total Time: 0.0219s             ││
# │└──────────────────────────���───────────────────┘│
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │               Optimizer: 0.0003s               │
# │┌──────────────────────────────────────────────┐│
# ││        Build Side Probe Side: 0.0000s        ││
# ││           Column Lifetime: 0.0000s           ││
# ││           Common Aggregate: 0.0000s          ││
# ││        Common Subexpressions: 0.0000s        ││
# ││      Compressed Materialization: 0.0000s     ││
# ││          Cte Filter Pusher: 0.0000s          ││
# ││             Deliminator: 0.0000s             ││
# ││           Duplicate Groups: 0.0000s          ││
# ││         Empty Result Pullup: 0.0000s         ││
# ││         Expression Rewriter: 0.0000s         ││
# ││              Extension: 0.0000s              ││
# ││            Filter Pullup: 0.0000s            ││
# ││           Filter Pushdown: 0.0000s           ││
# ││              In Clause: 0.0000s              ││
# ││         Join Filter Pushdown: 0.0000s        ││
# ││              Join Order: 0.0002s             ││
# ││         Late Materialization: 0.0000s        ││
# ││            Limit Pushdown: 0.0000s           ││
# ││           Materialized Cte: 0.0000s          ││
# ││             Regex Range: 0.0000s             ││
# ││            Reorder Filter: 0.0000s           ││
# ││          Sampling Pushdown: 0.0000s          ││
# ││        Statistics Propagation: 0.0000s       ││
# ││             Sum Rewriter: 0.0000s            ││
# ││                Top N: 0.0000s                ││
# ││           Unnest Rewriter: 0.0000s           ││
# ││            Unused Columns: 0.0000s           ││
# │└──────────────────────────────────────────────┘│
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │            Physical planner: 0.0000s           │
# │┌──────────────────────────────────────────────┐│
# ││            Column Binding: 0.0000s           ││
# ││             Create Plan: 0.0000s             ││
# ││            Resolve Types: 0.0000s            │���
# │└──────────────────────────────────────────────┘│
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │                Planner: 0.0015s                │
# │┌──────────────────────────────────────────────┐│
# ││               Binding: 0.0015s               ││
# │└──────────────────────────────────────────────┘│
# └─────────────────────────────────────────��──────┘
# ┌───────────────────────────┐
# │           QUERY           │
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │      STREAMING_LIMIT      │
# │    ────────────────────   │
# │           5 Rows          │
# │          (0.00s)          │
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │         TABLE_SCAN        │
# │    ────────────────────   │
# │         Function:         │
# │        READ_PARQUET       │
# │                           │
# │        Projections:       │
# │            guid           │
# │   social_social_network   │
# │      private_private      │
# │productivity_word_processin│
# │             g             │
# │         news_news         │
# │    social_communication   │
# │ productivity_spreadsheets │
# │content_creation_photo_edit│
# │         _creation         │
# │       search_search       │
# │     productivity_other    │
# │entertainment_music_audio_s│
# │          treaming         │
# │finance_banking_and_account│
# │            ing            │
# │        games_other        │
# │    entertainment_other    │
# │    education_education    │
# │  productivity_programming │
# │ productivity_presentations│
# │    reference_reference    │
# │     shopping_shopping     │
# │     other_unclassified    │
# │     recreation_travel     │
# │entertainment_video_streami│
# │             ng            │
# │     games_video_games     │
# │      productivity_crm     │
# │         mail_mail         │
# │ social_communication_live │
# │content_creation_video_audi│
# │      o_edit_creation      │
# │productivity_project_manage│
# │            ment           │
# │content_creation_web_design│
# │        _development       │
# │                           │
# │         4096 Rows         │
# │          (0.02s)          │
# └───────────────────────────┘
#                                guid  social_social_network  private_private  \
# 0  00010ab0daf7426b813be3de1288b9a0                   2466             <NA>
# 1  00052d76ed974971b466e32b9388c218                1921190          2967408
# 2  0009c1d03194477ca9f581169f26f974                   <NA>             <NA>
# 3  0010f376c3214cd2bae5ea2e3fba2d4b                2367754             <NA>
# 4  0001c8444e8a42d9a38674f737886d0e                   <NA>             <NA>
#
#    productivity_word_processing  news_news  social_communication  \
# 0                          <NA>      26581                  <NA>
# 1                          <NA>      14350                101456
# 2                          <NA>      46181                  <NA>
# 3                        143195      67480                 69127
# 4                          <NA>       <NA>                  <NA>
#
#    productivity_spreadsheets  content_creation_photo_edit_creation  \
# 0                       <NA>                                  <NA>
# 1                       <NA>                                  <NA>
# 2                       <NA>                                  <NA>
# 3                    1587912                                  <NA>
# 4                       <NA>                                  <NA>
#
#    search_search  productivity_other  ...  other_unclassified  \
# 0         390184              194240  ...              549370
# 1         300999              107500  ...             1020627
# 2           <NA>                <NA>  ...               96395
# 3         470707              169485  ...             1152117
# 4         261921                <NA>  ...             1191621
#
#    recreation_travel  entertainment_video_streaming  games_video_games  \
# 0             615652                         452756               <NA>
# 1               <NA>                        3128489               <NA>
# 2               <NA>                           <NA>               <NA>
# 3             440325                        2529469               <NA>
# 4              83900                        3984708               <NA>
#
#    productivity_crm  mail_mail  social_communication_live  \
# 0              <NA>       <NA>                       <NA>
# 1              <NA>      10731                       <NA>
# 2              <NA>       <NA>                       <NA>
# 3              <NA>     819647                       <NA>
# 4              <NA>     526094                       <NA>
#
#    content_creation_video_audio_edit_creation  \
# 0                                        <NA>
# 1                                        <NA>
# 2                                        <NA>
# 3                                        <NA>
# 4                                        <NA>
#
#    productivity_project_management  content_creation_web_design_development
# 0                             <NA>                                     <NA>
# 1                             <NA>                                   163385
# 2                             <NA>                                     <NA>
# 3                             <NA>                                     <NA>
# 4                             <NA>                                     <NA>
#
# [5 rows x 29 columns]

# %%
parquet_path = "/Users/couch/intel_research/data/webcat_0000_part_00.parquet"
view_name = "webcat_view_V2"

con.execute(f"""
    CREATE VIEW {view_name} AS 
    SELECT * FROM read_parquet('{parquet_path}');
""")

con.execute(f"SELECT * FROM {view_name} LIMIT 5").fetchdf()
# Out:
# ┌─────────────────────────────────────┐
# │┌───────────────────────────────────┐│
# ││    Query Profiling Information    ││
# │└───────────────────────────────────┘│
# └─────────────────────────────────────┘
# SELECT * FROM webcat_view_V2 LIMIT 5
# ┌────────────────────────────────────────────────┐
# │┌──────────────────────────────────────────────┐│
# ││              Total Time: 0.0403s             ││
# │└─────────────────────────���────────────────────┘│
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │               Optimizer: 0.0036s               │
# │┌──────────────────────────────────────────────┐│
# ││        Build Side Probe Side: 0.0000s        ││
# ││           Column Lifetime: 0.0000s           ││
# ││           Common Aggregate: 0.0000s          ││
# ││        Common Subexpressions: 0.0000s        ││
# ││      Compressed Materialization: 0.0000s     ││
# ││          Cte Filter Pusher: 0.0000s          ││
# ││             Deliminator: 0.0000s             ││
# ││           Duplicate Groups: 0.0000s          ││
# ││         Empty Result Pullup: 0.0000s         ││
# ││         Expression Rewriter: 0.0000s         ││
# ││              Extension: 0.0000s              ││
# ││            Filter Pullup: 0.0000s            ││
# ││           Filter Pushdown: 0.0000s           ││
# ││              In Clause: 0.0000s              ││
# ││         Join Filter Pushdown: 0.0000s        ││
# ││              Join Order: 0.0001s             ││
# ││         Late Materialization: 0.0000s        ││
# ││            Limit Pushdown: 0.0000s           ││
# ││           Materialized Cte: 0.0000s          ││
# ││             Regex Range: 0.0000s             ││
# ││            Reorder Filter: 0.0000s           ││
# ││          Sampling Pushdown: 0.0000s          ││
# ││        Statistics Propagation: 0.0002s       ││
# ││             Sum Rewriter: 0.0000s            ││
# ││                Top N: 0.0000s                ││
# ││           Unnest Rewriter: 0.0000s           ││
# ││            Unused Columns: 0.0032s           ││
# │└──────────────────────────────────────────────┘│
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │            Physical planner: 0.0000s           │
# │┌──────────────────────────────────────────────┐│
# ││            Column Binding: 0.0000s           ││
# ││             Create Plan: 0.0000s             ││
# ││            Resolve Types: 0.0000s            ���│
# │└──────────────────────────────────────────────┘│
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │                Planner: 0.0010s                │
# │┌──────────────────────────────────────────────┐│
# ││               Binding: 0.0010s               ││
# │└──────────────────────────────────────────────┘│
# └────────────────────────────────────────��───────┘
# ┌───────────────────────────┐
# │           QUERY           │
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │      STREAMING_LIMIT      │
# │    ────────────────────   │
# │           5 Rows          │
# │          (0.00s)          │
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │         TABLE_SCAN        │
# │    ────────────────────   │
# │         Function:         │
# │        READ_PARQUET       │
# │                           │
# │        Projections:       │
# │          load_ts          │
# │          batch_id         │
# │
#               load_ts         batch_id  \
# 0 2021-06-11 03:12:58  20210610-200228
# 1 2021-06-11 03:12:58  20210610-200228
# 2 2021-06-11 03:12:58  20210610-200228
# 3 2021-06-11 03:12:58  20210610-200228
# 4 2021-06-11 03:12:58  20210610-200228
#
#                                            audit_zip  \
# 0  2021061003-i-04a9a906e1cd5620c-Nza8Wx4VDJjXb7j...
# 1  2021061003-i-04a9a906e1cd5620c-Nza8Wx4VDJjXb7j...
# 2  2021061003-i-04a9a906e1cd5620c-Nza8Wx4VDJjXb7j...
# 3  2021061003-i-04a9a906e1cd5620c-Nza8Wx4VDJjXb7j...
# 4  2021061003-i-04a9a906e1cd5620c-Nza8Wx4VDJjXb7j...
#
#                     audit_internal_path                              guid  \
# 0  V8_2_WEB_CAT_USAGE_20210610134711.V8  000091c0adc149389235ed2c5f15a59e
# 1  V8_2_WEB_CAT_USAGE_20210610134711.V8  000091c0adc149389235ed2c5f15a59e
# 2  V8_2_WEB_CAT_USAGE_20210610134711.V8  000091c0adc149389235ed2c5f15a59e
# 3  V8_2_WEB_CAT_USAGE_20210610134711.V8  000091c0adc149389235ed2c5f15a59e
# 4  V8_2_WEB_CAT_USAGE_20210610134711.V8  000091c0adc149389235ed2c5f15a59e
#
#    interval_start_utc    interval_end_utc interval_local_start  \
# 0 2021-06-09 03:43:09 2021-06-10 03:45:19  2021-06-09 13:43:09
# 1 2021-06-09 03:43:09 2021-06-10 03:45:19  2021-06-09 13:43:09
# 2 2021-06-09 03:43:09 2021-06-10 03:45:19  2021-06-09 13:43:09
# 3 2021-06-09 03:43:09 2021-06-10 03:45:19  2021-06-09 13:43:09
# 4 2021-06-09 03:43:09 2021-06-10 03:45:19  2021-06-09 13:43:09
#
#    interval_local_end         dt browser parent_category  sub_category  \
# 0 2021-06-10 13:45:19 2021-06-09  chrome       reference     reference
# 1 2021-06-10 13:45:19 2021-06-09    edge    productivity         other
# 2 2021-06-10 13:45:19 2021-06-09  chrome           other  unclassified
# 3 2021-06-10 13:45:19 2021-06-09  chrome    productivity         other
# 4 2021-06-10 13:45:19 2021-06-09  chrome          search        search
#
#    duration_ms  page_load_count  site_count  domain_count  page_visit_count
# 0        36087                1           1             1                 4
# 1        21667                2           2             1                 3
# 2       296422               33          24             2                89
# 3         4924                2           1             1                 2
# 4        80042               24          14             1                18
# audit_zip         │
# │    audit_internal_path    │
# │            guid           │
# │     interval_start_utc    │
# │      interval_end_utc     │
# │    interval_local_start   │
# │     interval_local_end    │
# │             dt            │
# │          browser          │
# │      parent_category      │
# │        sub_category       │
# │        duration_ms        │
# │      page_load_count      │
# │         site_count        │
# │        domain_count       │
# │      page_visit_count     │
# │                           │
# │         4096 Rows         │
# │          (0.03s)          │
# └───────────────────────────┘

# %%
con.execute(f"SELECT DISTINCT parent_category, sub_category FROM {view_name} ORDER BY parent_category").fetchdf()
# Out:
# ┌─────────────────────────────────────┐
# │┌───────────────────────────────────┐│
# ││    Query Profiling Information    ││
# │└───────────────────────────────────┘│
# └─────────────────────────────────────┘
# SELECT DISTINCT parent_category, sub_category FROM webcat_view_V2 ORDER BY parent_category
# ┌────────────────────────────────────────────────┐
# │┌──────────────────────────────────────────────┐│
# ││              Total Time: 0.103s              ││
# │└───────���──────────────────────────────────────┘│
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │               Optimizer: 0.0012s               │
# │┌──────────────────────────────────────────────┐│
# ││        Build Side Probe Side: 0.0000s        ││
# ││           Column Lifetime: 0.0000s           ││
# ││           Common Aggregate: 0.0000s          ││
# ││        Common Subexpressions: 0.0000s        ││
# ││      Compressed Materialization: 0.0000s     ││
# ││          Cte Filter Pusher: 0.0000s          ││
# ││             Deliminator: 0.0000s             ││
# ││           Duplicate Groups: 0.0000s          ││
# ││         Empty Result Pullup: 0.0000s         ││
# ││         Expression Rewriter: 0.0002s         ││
# ││              Extension: 0.0000s              ││
# ││            Filter Pullup: 0.0000s            ││
# ││           Filter Pushdown: 0.0000s           ││
# ││              In Clause: 0.0000s              ││
# ││         Join Filter Pushdown: 0.0000s        ││
# ││              Join Order: 0.0009s             ││
# ││         Late Materialization: 0.0000s        ││
# ││            Limit Pushdown: 0.0000s           ││
# ││           Materialized Cte: 0.0000s          ││
# ││             Regex Range: 0.0000s             ││
# ││            Reorder Filter: 0.0000s           ││
# ││          Sampling Pushdown: 0.0000s          ││
# ││        Statistics Propagation: 0.0000s       ││
# ││             Sum Rewriter: 0.0000s            ││
# ││                Top N: 0.0000s                ││
# ││           Unnest Rewriter: 0.0000s           ││
# ││            Unused Columns: 0.0000s           ││
# │└──────────────────────────────────────────────┘│
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │            Physical planner: 0.0005s           │
# │┌──────────────────────────────────────────────┐│
# ││            Column Binding: 0.0000s           ││
# ││             Create Plan: 0.0004s             ││
# ││            Resolve Types: 0.0000s            ││
# │└──────────────────────────────────────────────┘│
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │                Planner: 0.0026s                │
# │┌──────────────────────────────────────────────┐│
# ││               Binding: 0.0026s               ││
# │└──────────────────────────────────────────────┘│
# └──────────────────────��─────────────────────────┘
# ┌───────────────────────────┐
# │           QUERY           │
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │          ORDER_BY         │
# │    ────────────────────   │
# │ memory.main.webcat_view_V2│
# │    .parent_category ASC   │
# │                           │
# │          28 Rows          │
# │          (0.01s)          │
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │       HASH_GROUP_BY       │
# │    ────────────────────   │
# │          Groups:          │
# │             #0            │
# │             #1            │
# │                           │
# │          28 Rows          │
# │          (0.66s)          │
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │         PROJECTION        │
# │    ────────────────────   │
# │      parent_category      │
# │        sub_category       │
# │                           │
# │       21354922 Rows       │
# │          (0.00s)          │
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │         TABLE_SCAN        │
# │    ────────────────────   │
# │         Function:         │
# │        READ_PARQUET       │
# │                           │
# │        Projections:       │
# │      parent_category      │
# │        sub_category       │
# │                           │
# │    Total Files Read: 1    │
# │                           │
# │       21354922 Rows       │
# │          (0.16s)          │
# └───────────────────────────┘
#      parent_category               sub_category
# 0   content creation   web design / development
# 1   content creation        photo edit/creation
# 2   content creation  video/audio edit/creation
# 3          education                  education
# 4      entertainment            video streaming
# 5      entertainment    music / audio streaming
# 6      entertainment                      other
# 7            finance     banking and accounting
# 8              games                      other
# 9              games                video games
# 10              mail                       mail
# 11              news                       news
# 12             other               unclassified
# 13           private                    private
# 14      productivity            word processing
# 15      productivity                      other
# 16      productivity                        crm
# 17      productivity              presentations
# 18      productivity                programming
# 19      productivity               spreadsheets
# 20      productivity         project management
# 21        recreation                     travel
# 22         reference                  reference
# 23            search                     search
# 24          shopping                   shopping
# 25            social             social network
# 26            social       communication - live
# 27            social              communication

# %%
con.execute(f"SELECT parent_category, (SUM(duration_ms)/60000) AS duration_min FROM {view_name} GROUP BY parent_category ORDER BY parent_category").fetchdf()
# Out:
# ┌─────────────────────────────────────┐
# │┌───────────────────────────────────┐│
# ││    Query Profiling Information    ││
# │└───────────────────────────────────┘│
# └─────────────────────────────────────┘
# SELECT parent_category, (SUM(duration_ms)/60000) AS duration_min FROM webcat_view_V2 GROUP BY parent_category ORDER BY parent_category
# ┌────────────────────────────────────────────────┐
# │┌──────────────────────────────────────────────┐│
# ││              Total Time: 0.0683s             ││
# │└──────────────────────────────────────────────┘│
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │               Optimizer: 0.0003s               │
# │┌──────────────────────────────────────────────┐│
# ││        Build Side Probe Side: 0.0000s        ││
# ││           Column Lifetime: 0.0000s           ││
# ││           Common Aggregate: 0.0000s          ││
# ││        Common Subexpressions: 0.0000s        ││
# ││      Compressed Materialization: 0.0000s     ││
# ││          Cte Filter Pusher: 0.0000s          ││
# ││             Deliminator: 0.0000s             ││
# ││           Duplicate Groups: 0.0000s          ││
# ││         Empty Result Pullup: 0.0000s         ││
# ││         Expression Rewriter: 0.0000s         ││
# ││              Extension: 0.0000s              ││
# ││            Filter Pullup: 0.0000s            ││
# ││           Filter Pushdown: 0.0000s           ││
# ││              In Clause: 0.0000s              ││
# ││         Join Filter Pushdown: 0.0000s        ││
# ││              Join Order: 0.0002s             ││
# ││         Late Materialization: 0.0000s        ││
# ││            Limit Pushdown: 0.0000s           ││
# ││           Materialized Cte: 0.0000s          ││
# ││             Regex Range: 0.0000s             ││
# ││            Reorder Filter: 0.0000s           ││
# ││          Sampling Pushdown: 0.0000s          ││
# ││        Statistics Propagation: 0.0000s       ││
# ││             Sum Rewriter: 0.0000s            ││
# ││                Top N: 0.0000s                ││
# ││           Unnest Rewriter: 0.0000s           ││
# ││            Unused Columns: 0.0000s           ││
# │└──────────────────────────────────────────────┘│
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │            Physical planner: 0.0000s           │
# │┌──────────────────────────────────────────────┐│
# ││            Column Binding: 0.0000s           ││
# ││             Create Plan: 0.0000s             ││
# ││            Resolve Types: 0.0000s            ││
# │└──────────────────────────────────────────────┘│
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │                Planner: 0.0013s                │
# │┌──────────────────────────────────────────────┐│
# ││               Binding: 0.0013s               ││
# │└──────────────────────────────────────────────┘│
# └────────────────────────────────────────────────┘
# ┌───────────────────────────┐
# │           QUERY           │
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │          ORDER_BY         │
# │    ────────────────────   │
# │ memory.main.webcat_view_V2│
# │    .parent_category ASC   │
# │                           │
# │          15 Rows          │
# │          (0.00s)          │
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │         PROJECTION        │
# │    ────────────────────   │
# │      parent_category      │
# │        duration_min       │
# │                           │
# │          15 Rows          │
# │          (0.00s)          │
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │       HASH_GROUP_BY       │
# │    ────────────────────   │
# │         Groups: #0        │
# │    Aggregates: sum(#1)    │
# │                           │
# │          15 Rows          │
# │          (0.09s)          │
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │         PROJECTION        │
# │    ────────────────────   │
# │      parent_category      │
# │        duration_ms        │
# │                           │
# │       21354922 Rows       │
# │          (0.00s)          │
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │         TABLE_SCAN        │
# │    ────────────────────   │
# │         Function:         │
# │        READ_PARQUET       │
# │                           │
# │        Projections:       │
# │      parent_category      │
# │        duration_ms        │
# │                           │
# │    Total Files Read: 1    │
# │                           │
# │       21354922 Rows       │
# │          (0.47s)          │
# └───────────────────────────┘
#      parent_category  duration_min
# 0   content creation  3.021983e+06
# 1          education  1.259095e+07
# 2      entertainment  2.366244e+08
# 3            finance  5.703987e+06
# 4              games  1.133628e+07
# 5               mail  3.028810e+07
# 6               news  1.188503e+07
# 7              other  3.104597e+08
# 8            private  2.071968e+08
# 9       productivity  2.163635e+07
# 10        recreation  2.630261e+06
# 11         reference  8.517189e+06
# 12            search  4.878572e+07
# 13          shopping  2.289834e+07
# 14            social  4.892312e+07

# %%
con.execute(f"SELECT parent_category, (SUM(duration_ms)/3600000) AS duration_hr FROM {view_name} GROUP BY parent_category ORDER BY parent_category").fetchdf()
# Out:
# ┌─────────────────────────────────────┐
# │┌───────────────────────────────────┐│
# ││    Query Profiling Information    ││
# │└───────────────────────────────────┘│
# └─────────────────────────────────────┘
# SELECT parent_category, (SUM(duration_ms)/3600000) AS duration_hr FROM webcat_view_V2 GROUP BY parent_category ORDER BY parent_category
# ┌────────────────────────────────────────────────┐
# │┌──────────────────────────────────────────────┐│
# ││              Total Time: 0.0705s             ││
# │└──────────────────────────────────────────────┘│
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │               Optimizer: 0.0003s               │
# │┌──────────────────────────────────────────────┐│
# ││        Build Side Probe Side: 0.0000s        ││
# ││           Column Lifetime: 0.0000s           ││
# ││           Common Aggregate: 0.0000s          ││
# ││        Common Subexpressions: 0.0000s        ││
# ││      Compressed Materialization: 0.0000s     ││
# ││          Cte Filter Pusher: 0.0000s          ││
# ││             Deliminator: 0.0000s             ││
# ││           Duplicate Groups: 0.0000s          ││
# ││         Empty Result Pullup: 0.0000s         ││
# ││         Expression Rewriter: 0.0000s         ││
# ││              Extension: 0.0000s              ││
# ││            Filter Pullup: 0.0000s            ││
# ││           Filter Pushdown: 0.0000s           ││
# ││              In Clause: 0.0000s              ││
# ││         Join Filter Pushdown: 0.0000s        ││
# ││              Join Order: 0.0002s             ││
# ││         Late Materialization: 0.0000s        ││
# ││            Limit Pushdown: 0.0000s           ││
# ││           Materialized Cte: 0.0000s          ││
# ││             Regex Range: 0.0000s             ││
# ││            Reorder Filter: 0.0000s           ││
# ││          Sampling Pushdown: 0.0000s          ││
# ││        Statistics Propagation: 0.0000s       ││
# ││             Sum Rewriter: 0.0000s            ││
# ││                Top N: 0.0000s                ││
# ││           Unnest Rewriter: 0.0000s           ││
# ││            Unused Columns: 0.0000s           ││
# │└──────────────────────────────────────────────┘│
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │            Physical planner: 0.0000s           │
# │┌──────────────────────────────────────────────┐│
# ││            Column Binding: 0.0000s           ││
# ││
#      parent_category   duration_hr
# 0   content creation  5.036638e+04
# 1          education  2.098492e+05
# 2      entertainment  3.943740e+06
# 3            finance  9.506644e+04
# 4              games  1.889379e+05
# 5               mail  5.048017e+05
# 6               news  1.980839e+05
# 7              other  5.174328e+06
# 8            private  3.453281e+06
# 9       productivity  3.606059e+05
# 10        recreation  4.383769e+04
# 11         reference  1.419532e+05
# 12            search  8.130954e+05
# 13          shopping  3.816391e+05
# 14            social  8.153854e+05
#       Create Plan: 0.0000s             ││
# ││            Resolve Types: 0.0000s            ││
# │└──────────────────────────────────────────────┘│
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │                Planner: 0.0036s                │
# │┌──────────────────────────────────────────────┐│
# ││               Binding: 0.0036s               ││
# │└──────────────────────────────────────────────┘│
# └───────��────────────────────────────────────────┘
# ┌───────────────────────────┐
# │           QUERY           │
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │          ORDER_BY         │
# │    ────────────────────   │
# │ memory.main.webcat_view_V2│
# │    .parent_category ASC   │
# │                           │
# │          15 Rows          │
# │          (0.01s)          │
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │         PROJECTION        │
# │    ────────────────────   │
# │      parent_category      │
# │        duration_hr        │
# │                           │
# │          15 Rows          │
# │          (0.00s)          │
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │       HASH_GROUP_BY       │
# │    ────────────────────   │
# │         Groups: #0        │
# │    Aggregates: sum(#1)    │
# │                           │
# │          15 Rows          │
# │          (0.11s)          │
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │         PROJECTION        │
# │    ────────────────────   │
# │      parent_category      │
# │        duration_ms        │
# │                           │
# │       21354922 Rows       │
# │          (0.00s)          │
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │         TABLE_SCAN        │
# │    ────────────────────   │
# │         Function:         │
# │        READ_PARQUET       │
# │                           │
# │        Projections:       │
# │      parent_category      │
# │        duration_ms        │
# │                           │
# │    Total Files Read: 1    │
# │                           │
# │       21354922 Rows       │
# │          (0.44s)          │
# └───────────────────────────┘

# %%
con.execute(f"SELECT parent_category, sub_category, (SUM(duration_ms)/3600000) AS duration_hr FROM {view_name} GROUP BY parent_category, sub_category ORDER BY parent_category").fetchdf()
# Out:
# ┌─────────────────────────────────────┐
# │┌───────────────────────────────────┐│
# ││    Query Profiling Information    ││
# │└───────────────────────────────────┘│
# └─────────────────────────────────────┘
# SELECT parent_category, sub_category, (SUM(duration_ms)/3600000) AS duration_hr FROM webcat_view_V2 GROUP BY parent_category, sub_category ORDER BY parent_category
# ┌────────────────────────────────────────────────┐
# │┌──────────────────────────────────────────────┐│
# ││              Total Time: 0.130s              ││
# │└──────────────────────────────────────────────┘│
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │               Optimizer: 0.0008s               │
# │┌──────────────────────────────────────────────┐│
# ││        Build Side Probe Side: 0.0000s        ││
# ││           Column Lifetime: 0.0000s           ││
# ││           Common Aggregate: 0.0000s          ││
# ││        Common Subexpressions: 0.0000s        ││
# ││      Compressed Materialization: 0.0000s     ││
# ���│          Cte Filter Pusher: 0.0000s          ││
# ││             Deliminator: 0.0000s             ││
# ││           Duplicate Groups: 0.0000s          ││
# ││         Empty Result Pullup: 0.0000s         ││
# ││         Expression Rewriter: 0.0001s         ││
# ││              Extension: 0.0000s              ││
# ││            Filter Pullup: 0.0000s            ││
# ││           Filter Pushdown: 0.0003s           ││
# ││              In Clause: 0.0000s              ││
# ││         Join Filter Pushdown: 0.0000s        ││
# ││              Join Order: 0.0002s             ││
# ││         Late Materialization: 0.0000s        ││
# ││            Limit Pushdown: 0.0000s           ││
# ││           Materialized Cte: 0.0000s          ││
# ││             Regex Range: 0.0000s             ││
# ││            Reorder Filter: 0.0000s           ││
# ││          Sampling Pushdown: 0.0000s          │��
# ││        Statistics Propagation: 0.0001s       ││
# ││             Sum Rewriter: 0.0000s            ││
# ││                Top N: 0.0000s                ││
# ││           Unnest Rewriter: 0.0000s           ││
# ││            Unused Columns: 0.0002s           ││
# │└──────────────────────────────────────────────┘│
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │            Physical planner: 0.0001s           │
# │┌──────────────────────────────────────────────┐│
# ││            Column Binding: 0.0000s           ││
# ││             Create Plan: 0.0000s             ││
# ││            Resolve Types: 0.0000s            ││
# │└──────────────────────────────────────────────┘│
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │                Planner: 0.0031s                │
# │┌──────────────────────────────────────────────┐│
# ││               Binding: 0.0031s               ││
# │└──────────────────────────────────────────────┘��
# └────────────────────────────────────────────────┘
# ┌───────────────────────────┐
# │           QUERY           │
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │          ORDER_BY         │
# │    ────────────────────   │
# │ memory.main.webcat_view_V2│
# │    .parent_category ASC   │
# │                           │
# │          28 Rows          │
# │          (0.00s)          │
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │         PROJECTION        │
# │    ────────────────────   │
# │      parent_category      │
# │        sub_category       │
# │        duration_hr        │
# │                           │
# │          28 Rows          │
# │          (0.00s)          │
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │       HASH_GROUP_BY       │
# │    ────────────────────   │
# │          Groups:          │
# │             #0            │
# │             #1            │
# │                           │
# │    Aggregates: sum(#2)    │
# │                           │
# │          28 Rows          │
# │          (0.72s)          │
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │         PROJECTION        │
# │    ───���────────────────   │
# │      parent_category      │
# │        sub_category       │
# │        duration_ms        │
# │                           │
# │       21354922 Rows       │
# │          (0.00s)          │
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │         TABLE_SCAN        │
# │    ────────────────────   │
# │         Function:         │
# │        READ_PARQUET       │
# │                           │
# │        Projections:       │
# │      parent_category      │
# │        sub_category       │
# │        duration_ms        │
# │                           │
# │    Total Files Read: 1    │
# │                           │
# │       21354922 Rows       │
# │          (0.34s)          │
# └──────────────��────────────┘
#      parent_category               sub_category   duration_hr
# 0   content creation   web design / development  3.728031e+04
# 1   content creation  video/audio edit/creation  1.516382e+03
# 2   content creation        photo edit/creation  1.156969e+04
# 3          education                  education  2.098492e+05
# 4      entertainment                      other  3.180590e+05
# 5      entertainment    music / audio streaming  3.271571e+04
# 6      entertainment            video streaming  3.592965e+06
# 7            finance     banking and accounting  9.506644e+04
# 8              games                video games  2.751150e+03
# 9              games                      other  1.861868e+05
# 10              mail                       mail  5.048017e+05
# 11              news                       news  1.980839e+05
# 12             other               unclassified  5.174328e+06
# 13           private                    private  3.453281e+06
# 14      productivity                programming  3.855818e+04
# 15      productivity              presentations  1.981444e+04
# 16      productivity               spreadsheets  9.506208e+04
# 17      productivity         project management  1.187506e+04
# 18      productivity            word processing  7.005605e+04
# 19      productivity                      other  1.250942e+05
# 20      productivity                        crm  1.458754e+02
# 21        recreation                     travel  4.383769e+04
# 22         reference                  reference  1.419532e+05
# 23            search                     search  8.130954e+05
# 24          shopping                   shopping  3.816391e+05
# 25            social              communication  1.803066e+05
# 26            social       communication - live  9.873301e+04
# 27            social             social network  5.363458e+05

# %%
con.execute(f"SELECT parent_category, sub_category, SUM(duration_ms) FROM {view_name} GROUP BY parent_category, sub_category ORDER BY parent_category").fetchdf()
